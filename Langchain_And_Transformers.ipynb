# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#   Obtaining dependency information for langchain-huggingface from https://files.pythonhosted.org/packages/4f/9b/86f1bb19739ca510503abb4dca65deff9c95dc318bde2e51ce8c4fa7847c/langchain_huggingface-0.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for huggingface-hub>=0.23.0 from https://files.pythonhosted.org/packages/85/1f/21e2fb9564b53122105866c26daeb239911b003d1df3867dd113cf5a7694/huggingface_hub-0.26.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for langchain-core<0.4,>=0.3.0 from https://files.pythonhosted.org/packages/ce/4a/a6499d93805c3e6316e641b6934e23c98c011d00b9a2138835d567e976e5/langchain_core-0.3.12-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for sentence-transformers>=2.6.0 from https://files.pythonhosted.org/packages/e7/78/2835963e7c03865392e88008629d9b81db386fedfcfac006d5c6454b8ecf/sentence_transformers-3.2.0-py3-none-any.whl.metadata
# ...

# %%
## Environment secret keys
import os
sec_key = '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'
print(sec_key)
# Out:
# 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

# %% [markdown]
# # HuggingFaceEndpoint

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]= sec_key

# %%
api_token = sec_key 
inference = InferenceApi(repo_id=repo_id, token=api_token)

repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id= repo_id, repetition_penalty=1.2)
# Out:
# C:\Users\shesh\anaconda3\envs\DeepLearning\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %% [raw]
# top_k= 50 # Top-k controls the next token selection
# top_p=0.9  # Top-p controls randomness
# repetition_penalty=1.2  # Increase to penalize repetitions

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', huggingfacehub_api_token='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', repetition_penalty=1.2, stop_sequences=[], server_kwargs={}, model_kwargs={}, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
llm.invoke("What is machine learning")
# Out:
# "?\n\nMachine learning (ML) is a type of artificial intelligence that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning focuses on the development of computer programs that can access data and use it to learn for themselves. The process of learning begins with observations or data, such as examples, direct instruction, or lessons in order to look for patterns in data and make better decisions in the future based on the examples that we provide. The primary aim is to allow the computers to learn automatically without human intervention or assistance and adjust actions accordingly.\n\nWhat are some applications of machine learning?\n\n- Recommendation Engines: Netflix uses ML algorithms to predict user preferences for movies. Amazon’s recommendation system also utilizes ML to suggest products based on users' browsing history.\n- Image Recognition: Google Photos uses ML to identify people, places, object
# ...

# %%
llm.invoke("What is deep learning")
# Out:
# "? Deep learning is a subfield of machine learning (ML) that focuses on the development and application of artificial neural networks with many layers. These models are called “deep” because they have multiple hidden layers between their input and output layers, allowing them to learn increasingly abstract representations of data at each layer.\n\nDeep learning has achieved remarkable success in tasks such as image classification, speech recognition, natural language processing, and game playing, surpassing human-level performance in some cases. This is due to its ability to automatically extract features from raw data without explicit feature engineering, making it easier to scale up ML projects and achieve state-of-the-art results.\n\nThe key advantage of deep learning over traditional ML algorithms lies in its ability to handle large amounts of complex data by efficiently modeling high-dimensional relationships within the data. The increased capacity of these models comes from hav
# ...

# %%
llm.invoke("Explain the concept of bias-variance tradeoff in machine learning.")
# Out:
# "\n\nThe bias-variance tradeoff is a fundamental concept in machine learning that describes the relationship between the complexity (or flexibility) of a model and its generalization performance on unseen data. It helps us understand how to balance simplicity and accuracy when building models, as both too simple or overly complex models can lead to poor predictive power.\n\n1. Bias: This refers to the tendency of a model to systematically underestimate or overestimate certain outcomes due to simplifying assumptions made during the modeling process. A high bias model may miss important relationships in the data, resulting in a less accurate fit to the training set but potentially better generalization performance on new data points. Examples include linear regression with only one feature or decision trees with few splits.\n\n2. Variance: This measures the sensitivity of the model's predictions to small changes in the training dataset. A low variance model captures the underlying patt
# ...

# %%
llm.invoke("What is the significance of p-value in hypothesis testing?")
# Out:
# "\nThe p-value is a measure used in statistical hypothesis testing to determine the probability that the observed results could have occurred by chance, assuming the null hypothesis is true. A smaller p-value indicates stronger evidence against the null hypothesis and thus provides more support for the alternative hypothesis. In other words, if the p-value is small enough (commonly less than 0.05), it suggests that there is statistically significant evidence to reject the null hypothesis and accept the alternative hypothesis. However, it's important to note that a low p-value does not necessarily mean that we can draw causal conclusions; correlation doesn't imply causation. Furthermore, interpreting p-values requires considering the context of the study, including the research question, sample size, effect size, and potential confounding variables."

# %%
llm.invoke("working of ballmill")
# Out:
# ' in cement plant\n\nball mill for coal grinding in cement plants - wikipedia,the ball mill is a key piece of equipment for grinding crushed materials and it is widely used in production lines for powders such as cement silicates refractory material fertilizer glass ceramics etc.as well as for ore dressing of both ferrous and non-ferrous metals the ball mill can grind various ores and other materials either wet or dry.\n\ncement manufacturing process | phoenix cements ltd.,there are three stages involved in cement manufacture: raw material preparation, clinker production, and cement production. these stages are described below: 1. raw material preparation. limestone (calcium carbonate) clay shale iron ore gypsum silica sand coal and other minerals required for the production of cement are transported to the cement factory site from their respective quarries by rail, roadways or river ways. these raw materials are then crushed at the cement factory itself into small pieces of about si
# ...

# %%
llm.invoke("what ids E1 and E2 reaction")
# Out:
# '?\n\nE1 (Elimination, one bond breaking) is a type of chemical reaction that involves the removal of a molecule from a compound while forming two new products. It typically involves an alkyl halide or tosylate as the starting material, which loses a leaving group (such as Cl-, Br-, I-, OSO2-C6H4Me) along with a proton to form an alkene product and a carbocation intermediate. The carbocation can then react with a nucleophile to form another product if present in the reaction mixture.\n\nE2 (Elimination, two bonds breaking) is also a type of chemical elimination reaction but it occurs more readily than E1 because both the leaving group and a hydrogen atom attached to the carbon adjacent to the leaving group are removed at the same time, resulting in the formation of a double bond between the remaining carbons. This reaction requires base catalysis and results in the formation of an alkene and water as byproducts.'

# %%
llm.invoke("How does the random forest algorithm work, and when should you use it?")
# Out:
# "\n\nRandom Forest is a popular machine learning algorithm that belongs to the ensemble learning method. It works by constructing multiple decision trees during training time, each of which is trained on a different subset of the data and with a slightly different set of features. These trees are then aggregated in some way (usually by taking the majority vote) to make predictions for new instances. The idea behind Random Forests is to reduce overfitting and increase accuracy by combining many weak learners (decision trees) into a single strong learner.\n\nThe primary advantage of using Random Forest is its ability to handle large datasets with high dimensionality while maintaining relatively low computational complexity compared to other algorithms like Support Vector Machines or Neural Networks. Additionally, Random Forest provides an estimate of feature importance through a technique called Mean Decrease Impurity (MDI), making it easy to understand which variables have the most im
# ...

# %%
llm.invoke("What is transfer learning, and when should it be applied?")
# Out:
# '\nTransfer learning is a machine learning strategy where a pre-trained model on one task serves as the starting point for another related task. It allows us to leverage knowledge from previous training data to improve the performance of models in new tasks with less training data or time. Transfer learning can save significant computational resources and improve accuracy by avoiding overfitting, especially when dealing with small datasets or complex problems.\n\nThe best use case for transfer learning involves domains (or tasks) that are similar enough for the learned features to generalize well. For example:\n1. Image classification: You could start with an ImageNet-pretrained convolutional neural network (CNN), then fine-tune its last layers using your own dataset to classify different types of animals or objects specific to your domain. This way, you get better results than if you trained everything from scratch.\n2. Text analysis: Fine-tuning BERT (Bidirectional Encoder Represen
# ...

# %%
llm.invoke("How does transfer learning apply to pre-trained models like BERT or GPT?")
# Out:
# '\n\nTransfer learning is a machine learning approach where a model developed for one task is reused as the starting point (or "backbone") for another related task. This can significantly reduce the amount of data and time required to train an accurate model from scratch, especially when working with limited resources or complex tasks.\n\nIn the context of pre-trained models such as BERT (Bidirectional Encoder Representations from Transformers) or GPT (Generative Pre-training Transformer), these models are initially trained on large amounts of unlabeled text data using a technique called self-supervised learning. During this training phase, the model learns general language patterns, including how words relate to each other in context, part-of-speech, syntax, etc., without being explicitly taught any specific task or domain.\n\nOnce the pre-training process is complete, the weights of the model can be frozen, and additional layers can be added on top for fine-tuning on a specific dow
# ...

# %%
llm.invoke("What is reinforcement learning, and how is it applied in autonomous systems?")
# Out:
# "\nReinforcement Learning (RL) is a type of machine learning where an agent learns to make decisions by taking actions in an environment to achieve a goal. The agent receives feedback in the form of rewards or punishments for its actions, which guide it towards better decision-making over time.\n\nIn the context of autonomous systems, RL can be used to train robots, drones, self-driving cars, etc., to perform tasks efficiently and safely. For instance, a robot might use RL to learn how to grasp objects, while a self-driving car could employ RL to navigate through traffic optimally.\n\nThe core elements of reinforcement learning are:\n1. Agent: This is the entity that interacts with the environment. It takes observations from the environment and performs actions based on what it has learned so far.\n2. Environment: This is the world in which the agent operates. It provides sensory input to the agent and applies changes as a result of the agent's actions.\n3. Action Space: This defines
# ...

# %%
llm.invoke("How does natural language processing (NLP) work in AI applications?")
# Out:
# "\n\nNatural Language Processing (NLP) is a subfield of artificial intelligence that deals with the interaction between computers and humans through human languages. Here's a simplified explanation of how it works:\n\n1. **Text Preprocessing**: This is the first step where raw text data is cleaned up, standardized, and converted into a format that can be understood by machines. It involves tasks like tokenization (breaking down sentences into individual words), stemming (reducing words to their root form), and stopword removal (removing common words like 'and', 'the', etc., which don't add much meaning).\n\n2. **Part-of-Speech Tagging (POS)**: In this step, each word in the preprocessed text is labeled as a noun, verb, adjective, adverb, pronoun, etc. This helps the machine understand the role of each word in the sentence.\n\n3. **Named Entity Recognition (NER)**: NER identifies important named entities such as people, places, organizations, dates, and numbers in the text.\n\n4. **Pa
# ...

# %%
llm.invoke("How does a GPT model work for text generation?")
# Out:
# "\n\nA Generative Pre-trained Transformer (GPT) model is a type of deep learning model trained using the transformer architecture, specifically designed for generating human-like text. Here's a simplified explanation of how it works:\n\n1. **Pre-training**: The model is first pre-trained on a large corpus of text data, such as books or web pages. During this phase, the model learns to predict the next word in a sequence given the previous words, effectively teaching itself patterns and structures found in language. This process is unsupervised, meaning no specific task or label is provided.\n\n2. **Fine-tuning**: After pre-training, the model can be fine-tuned on a specific task, like question answering, translation, or text generation. For text generation, the model is trained to complete sentences or paragraphs given an initial context or prompt. Fine-tuning involves providing labeled examples so that the model learns to perform the desired task more accurately.\n\n3. **Generation*
# ...

# %%
llm.invoke("How do text-to-image models like DALL-E generate realistic images from text prompts?")
# Out:
# '\n\nText-to-image models, such as DALL-E, use a combination of deep learning techniques to generate images based on textual descriptions. Here\'s an overview of the key components involved:\n\n1. Pretraining: The model is first pretrained on a large dataset containing both image and text data. This could be pairs of images and their corresponding captions (e.g., "A photo of a dog playing fetch"), or it might involve more complex relationships between texts and images. For example, in the case of DALL-E, the training dataset consists of millions of pairs of texts that describe how things look and actual images of those things.\n\n2. Encoder: To process the input text, the model uses an encoder network, typically a transformer or convolutional neural network. The encoder converts the sequence of words into a fixed-length vector representation called a context vector. In some cases, additional information about the text may also be encoded, such as the position of each word within the 
# ...

# %%
api_token = sec_key 
inference = InferenceApi(repo_id=repo_id, token=api_token)

repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"
llm = HuggingFaceEndpoint(repo_id= repo_id, repetition_penalty=1.2)
# Out:
# C:\Users\shesh\anaconda3\envs\DeepLearning\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
llm.invoke("How can generative AI be used for data augmentation in machine learning?")
# Out:
# '\n=====================================================================\n\nGenerative AI models, such as Variational Autoencoders (VAEs) and Generative Adversarial Networks (GANs), can be used to generate new synthetic data points that are similar to the original training dataset. This technique is called data augmentation and it can help improve the performance of machine learning algorithms by increasing the size of the training set and reducing overfitting. By using a generative model to create additional data points, we can artificially inflate the size of our training set while maintaining its diversity and representativeness. In this way, data augmentation with generative AI can help improve the accuracy and robustness of machine learning models, particularly when working with small or imbalanced datasets.'

# %%
llm.invoke("What are some ethical challenges of generative AI in creative industries?")
# Out:
# "\n\nGenerative AI has the potential to revolutionize the way that content is created across a variety of different creative fields, such as music, writing, and visual art. However, there are also several ethical concerns related to using these technologies for creating original works of art. Here are just a few examples:\n\n1. Ownership and attribution - When an AI system generates new content, who owns the rights to that work? Is it the person or organization that trained the model, the developers who built the technology, or someone else entirely? And how should credit be attributed to those involved in its creation? These questions become even more complex when you consider cases where human input was used during the training process but not explicitly included in the final output.\n2. Bias and fairness - As with any automated decision-making tool, there's a risk that generative AI could perpetuate existing biases if the data used to train the models reflects discriminatory pract
# ...

# %%
from langchain import PromptTemplate, LLMChain

question = "Who won the 2024 Cricket World Cup in the year 2024 and who is the captain of the team?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm, prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'Who won the 2024 Cricket World Cup in the year 2024 and who is the captain of the team?', 'text': " The Cricket World Cup is an international cricket tournament that takes place every four years. It is organized by the International Cricket Council (ICC). As I don't have access to real-time information, I can't provide you with the name of the winning team or its captain for the 2024 Cricket World Cup as it hasn't taken place yet and the outcome remains unknown."}

# %%
question = "Who won the Cricket World Cup in the year 2011?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm, prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'Who won the Cricket World Cup in the year 2011?', 'text': " India hosted the ICC World Cup along with Sri Lanka and Bangladesh, which was played from February to April 2011. The final match took place at Wankhede Stadium in Mumbai on April 2, 2011 between India and Sri Lanka. India won the match by six wickets, thus winning their second Cricket World Cup after their triumphant win back in 1983 under Kapil Dev's captaincy. This victory brought immense joy and pride to millions of Indians across the world."}

# %%
question = "What are Rohit Sharma’s major achievements in international cricket?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm, prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'What are Rohit Sharma’s major achievements in international cricket?', 'text': ' \n\n1. Test Career Achievements:\n   - As of October 2021, Rohit has played 45 Tests and scored over 3687 runs at an average of 49.27 with a highest score of 212 against South Africa in 2019. He also has 11 centuries to his name.\n   \n2. ODI Career Achievements:\n   - In One Day Internationals (ODIs), Rohit has appeared in 233 matches scoring more than 9211 runs at an impressive average of around 48. \n   - His highest individual score is unbeaten 264 which he hit vs Sri Lanka in 2014. This remains the highest ever score by a batsman in ODIs. He has 29 centuries under his belt so far.\n\n3. T20I Career Achievements:\n   - In T20 internationals, Rohit has featured in 122 games where he amassed nearly 3000 runs with a strike rate close to 140.\n   - He holds the record for most sixes in T20Is (177).\n\n4. Other Notable Achievements:\n   - Rohit was part of the Indian team that won the ICC Cr
# ...

# %%
llm.invoke("How did Rohit Sharma’s career evolve from being a middle-order batsman to an opener?")
# Out:
# '\nRohit Sharma started his international cricket career as a middle-order batsman for India, often batting at number six or seven. However, in 2013, he was given the opportunity to open the innings in One Day Internationals (ODIs) during the Champions Trophy tournament in England. He grabbed this chance with both hands and scored two centuries in that tournament, including a record-breaking score of 264 against Sri Lanka. Since then, Rohit has established himself as one of the most successful opening batsmen in ODI cricket, scoring numerous hundreds and breaking several records along the way. In Test cricket too, he has been tried out as an opener since early 2019 and has found success there as well. His natural talent, hard work, and ability to adapt to different situations have helped him make this transition successfully.'

# %%
llm.invoke("How many centuries has Rohit Sharma scored in World Cups?")
# Out:
# '\n\n- Rohit Sharma, the captain of India’s One Day International (ODI) team and opener batsman, is one of the most prolific run scorers for his country. He holds a number of records at both international level as well as domestic cricket levels. In 2019 he became only the second Indian to score three hundred runs during an ODI world cup match against Pakistan on June 16th. With this achievement added to all previous scores across different editions of World cups since its inauguration back in 1975 till now; it brings total count up to seven centuries!'

# %%
llm.invoke("What makes Rohit Sharma’s batting technique so effective in limited-overs cricket?")
# Out:
# "\n\nRohit Sharma has established himself as one of the most successful opening batsmen in One Day International (ODI) and Twenty20 International (T20I) cricket, with a unique approach that combines solid defense, exquisite timing, power hitting, and inventive shot selection. Here are some key aspects of his batting technique:\n\n1. Strong Basics: Rohit has an orthodox grip and stance, which forms the foundation for his strokeplay. He stands tall, maintaining good balance and posture throughout his innings. This enables him to adapt to various bowling styles and deliveries effectively.\n2. Patience and Temperament: Despite being known for scoring at a brisk pace, Rohit is patient during the initial stages of his innings. He understands the importance of building an innings while minimizing risks against quality new ball attacks. This mindset helps him lay a strong platform before accelerating later on.\n3. Exceptional Hand-Eye Coordination: Rohit's hand-eye coordination is remarkable
# ...

# %% [markdown]
# # HuggingFacePipeline

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# C:\Users\shesh\anaconda3\envs\DeepLearning\lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\shesh\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x000001F8D0EF12E0>)

# %%
hf.invoke("Artificial intelligence has advanced so much that now machines can")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# "Artificial intelligence has advanced so much that now machines can perform complex tasks far beyond it would be impossible for humans.\n\nWhile most modern humans are not at all thrilled about the prospect, the United States' government has been doing something of a bit of good lately with it's new version of artificial intelligence.\n\nResearchers at Stanford University have now created a self-learning software which can predict what people might say through the voice of an individual within a certain time period—from a few minutes to a day. The software is extremely efficient, and it"

# %%
hf.invoke("In the year 2099, humanity had finally colonized Mars, but no one expected that")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# "In the year 2099, humanity had finally colonized Mars, but no one expected that a long journey through the Red Planet would change his mind. So it's with great sadness that we announce the release dates of the series:\n\nSpiral, a sequel to the original published by Vertigo in 2010, will debut in September. Read this report for details…\n\nSource: Vertigo\n\nShare this: Reddit\n\nTwitter\n\nFacebook\n\nTumblr\n\nGoogle\n\nMore\n\nEmail\n\nPrint\n\n\nLinkedIn\n\nPinterest\n\n\nPocket"

# %%
hf.invoke("Quantum physics suggests that reality might be")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 'Quantum physics suggests that reality might be made possible by a massive supercomputer (think of a supercomputing center, for example) or a supercomputer that can produce even an average of 10,000 calculations per second.\n\nIn fact, the first Nobel Prize of physicist Robert J. Feynman was awarded in 1931 to Walter W. T. Hall, who proposed a process where "quantum-structured computing could be the sole form of the natural language for describing a whole number," which he called the "universal language'

# %%
hf.invoke("John opened the mysterious envelope, only to find")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 'John opened the mysterious envelope, only to find that a few pages of his diary revealed that, despite the letter\'s contents, it did not contain anything incriminating. After some time the note was removed from his body and then the evidence was presented to a coroner.\n\nAlthough the detective who uncovered the case was convinced that the contents of the mystery letter were actually the letter\'s original contents, they found the handwriting to be "far from accurate and incomplete".\n\nOn August 25, 1975, another handwriting expert, David Doolittle,'

# %%
hf.invoke("The GPT-2 model can predict text based on prompts, but sometimes it generates")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 'The GPT-2 model can predict text based on prompts, but sometimes it generates responses that are completely useless. In particular, GPT-2 is a very good predictor of the words that someone has typed (not actually "writing" that word) as a result of previous text recognition (such as in an email sent to a friend).\n\nI personally like the simple approach, where GPT-2 can see a text for its own "text processing model" and use that model to interpret the text based on the user\'s prompt and prompts. Such model could then be'

# %%
hf.invoke("Data scientists discovered a new algorithm that could")
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# "Data scientists discovered a new algorithm that could better handle this new problem and would work in any language. It's called RNN. I'll write more on this subject soon so please keep an eye out for it!\n\nRNN\n\nRNN is a kind of artificial intelligence developed by Microsoft research firm Intel. The project has already reached the $40 million threshold on its first run.\n\nThe research company released an open sourced project on Oct. 11 that has been working on a new mathematical algorithm. This new algorithm is called"

# %%
## Use HuggingfacePipelines With Gpu
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id=model_id,
    task="text-generation",
    device_map="auto",  # Automatically selects GPU
    pipeline_kwargs={"max_new_tokens": 100}
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
my_chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
my_chain.invoke({"question":question})
# Out:
# 'Question: What is artificial intelligence?\n\nAnswer: Let\'s think step by step. When we examine the natural world, we always begin with a description of the object we are looking at. That description would be similar to what we are seeing. Of course, we do not know precisely what the objects we are looking at are. We can only see how their behavior responds to our description (see, for example, "We find a lot of plants in a valley"). It is not that we can simply pick out objects, they do not exist. In fact, many of them may'

# %%
question="What is deep learning?"
my_chain.invoke({"question":question})
# Out:
# "Question: What is deep learning?\n\nAnswer: Let's think step by step. You already have a good understanding of deep learning. And it's a huge field we have now all of a sudden come to, and you realize you can do much better.\n\nDeep learning is a real revolution in our understanding of life and everything that is going on. It helps us to make real decisions that are truly meaningful to us. We learn how most people do things when we use our technology and how they interact with the world, and that means we can actually make decisions based on our"

# %%
question="What is machine learning?"
my_chain.invoke({"question":question})
# Out:
# "Question: What is machine learning?\n\nAnswer: Let's think step by step. Let's say you are a professional engineer, a salesperson or a designer. You know your skills. If you are not in an office environment, you don't work.\n\nImagine that you are teaching a very talented person how to design a beautiful apartment building and then when they get to do it, you take the whole job and they give you that job for free. Now that you know how to build that skyscraper, you are going to hire some people and, after that, you"
